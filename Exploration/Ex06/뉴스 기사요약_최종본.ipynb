# %%
# !mkdir -p ~/aiffel/news_summarization/data
# !ln -s ~/data/*.csv ~/aiffel/news_summarization/data
# Out:
# ln: failed to create symbolic link '/aiffel/aiffel/news_summarization/data/Reviews.csv': File exists

# %%
# 불용어 정리  NLTK
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Step 1. 데이터 수집하기

# %%
# data = pd.read_csv(os.getenv("HOME")+"/aiffel/news_summarization/data/Reviews.csv", nrows=100000)
# print('전체 샘플수 :', (len(data)))

import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# %%
data.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...

# %%
data = data[['text', 'headlines']]
data.head()

#랜덤한 15개 샘플 출력
data.sample(15)
# Out:
#                                                     text  \
# 51680  South Africa's AB de Villiers slammed the fast...
# 77700  Arvind Panagariya, the Vice Chairman of policy...
# 30806  Hours after the Centre ordered security forces...
# 3709   Veteran actor Kader Khan, who recently passed ...
# 60917  Karnataka Governor VR Vala on Tuesday presente...
# 92492  IMF Chief Christine Lagarde has said, "The GST...
# 31648  Barcelona midfielder Arda Turan, currently on ...
# 96780  North Korea has slammed US President Donald Tr...
# 11467  A Qatar Airways flight with 103 passengers onb...
# 9692   Congress has fielded Manvendra Singh, former B...
# 33242  India's second-largest lender by market capita...
# 67725  A day after a stampede at Mumbai's Elphinstone...
# 26746  The Supreme Court has asked the Ministry of Pe...
# 59698  Facebook board member Peter Thiel has sold maj...
# 45627  Cryptocurrency Waltonchain's price plunged 20%...
#
#                                                headlines
# 51680  AB de Villiers hit ODIs' fastest hundred in 40...
# 77700  Arvind Panagariya quits as Niti Aayog Vice Cha...
# 30806  Encounter breaks out hrs after J&K Ramzan ceas...
# 3709   Veteran actor Kader Khan's funeral held in Canada
# 60917  7 Karnataka kids get bravery awards for saving...
# 92492  GST reform is really an act of courage: IMF Ch...
# 31648  BarÃÂ§a loanee handed record 16-match ban for...
# 96780  North Korea slams Donald Trump for being too m...
# 11467  Qatar Airways plane hits water tanker in Kolka...
# 9692   Congress fields BJP veteran's son against Raj ...
# 33242  Kotak Mahindra Bank's Q4 profit rises 15% to Ã...
# 67725  Like demonetisation, bullet train will kill ev...
# 26746  Does Petroleum Ministry think it is God: SC on...
# 59698  Peter Thiel sells majority of his stake in Fac...
# 45627  Crypto crashes 20% as firm tweets it won its o...

# %% [markdown]
# ### Step 2. 데이터 전처리하기 (추상적 요약)

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('Headlines 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# Headlines 열에서 중복을 배제한 유일한 샘플의 수 : 98280

# %%
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
print(data.isnull().sum())
# Out:
# text         0
# headlines    0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_headlines = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("headlines:", preprocess_sentence(temp_headlines, False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# headlines: great way to start the day

# %%
# 전체 Text 데이터에 대한 전처리
clean_text = []

for text in data['text']:
    processed = preprocess_sentence(text)
    clean_text.append(processed)
    
# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# Text 전처리 후 결과:  ['saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers', 'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit', 'new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history', 'aegon life iterm insurance plan customers enjoy tax benefits premiums paid save taxes plan provides life cover age years also customers options insure critical illnesses disability accidental death benefit rider life cover age years', 'speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju']

# %%
# 전체 Headlines 데이터에 대한 전처리
clean_headlines = []
for headlines in data['headlines']:
    processed_headlines = preprocess_sentence(headlines)
    clean_headlines.append(processed_headlines)
print("Headlines 전처리 후 결과: ", clean_headlines[:5])
# Out:
# Headlines 전처리 후 결과:  ['upgrad learner switches career ml al salary hike', 'delhi techie wins free food swiggy one year cred', 'new zealand end rohit sharma led india match winning streak', 'aegon life iterm insurance plan helps customers save tax', 'known hirani yrs metoo claims true sonam']

# %%
data['text'] = clean_text
data['headlinnes'] = clean_headlines

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
headlines_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(headlines_len)))
print('요약의 최대 길이 : {}'.format(np.max(headlines_len)))
print('요약의 평균 길이 : {}'.format(np.mean(headlines_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(headlines_len)
plt.title('Headlines')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Headlines')
plt.hist(headlines_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 18
# 요약의 평균 길이 : 9.553660024400163

# %%
text_max_len = 50 # 그래프보고 정하기
headlines_max_len = 14  # 그래프보고 정하기

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['text'])
below_threshold_len(headlines_max_len,  data['headlines'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.9998576657177715
# 전체 샘플 중 길이가 14 이하인 샘플의 비율: 0.9992069947132981

# %%
# # text와 summary 길이가 지정된 최대 길이를 초과하는 샘플을 제외
# filtered_data = data

# filtered_data = data.apply(lambda x: len(x['text']) <= text_max_len, axis=1)
# data = data.apply(lambda x: len(x['headlines']) <= headlines_max_len, axis=1)


# print('전체 샘플수 :', (len(data)))


data = data[data['text'].apply(
                lambda i: len(i.split())<=text_max_len)]
data = data[data['headlines'].apply(
                lambda i: len(i.split())<=headlines_max_len)]


print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98268

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit pg program mac...
# 1  kunal shah credit card bill payment platform c...
# 2  new zealand defeated india wickets fourth odi ...
# 3  aegon life iterm insurance plan customers enjo...
# 4  speaking sexual harassment allegations rajkuma...
#
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                           headlinnes  \
# 0   upgrad learner switches career ml al salary hike
# 1   delhi techie wins free food swiggy one year cred
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4           known hirani yrs metoo claims true sonam
#
#                                        decoder_input  \
# 0  sostoken upGrad learner switches to career in ...
# 1  sostoken Delhi techie wins free food from Swig...
# 2  sostoken New Zealand end Rohit Sharma-led Indi...
# 3  sostoken Aegon life iTerm insurance plan helps...
# 4  sostoken Have known Hirani for yrs, what if Me...
#
#                                       decoder_target
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...

# %%
encoder_input = np.array(data['text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [61719 29062 84285 ... 11737 65621 93458]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 19653

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 78615
# 훈련 레이블의 개수 : 78615
# 테스트 데이터의 개수 : 19653
# 테스트 레이블의 개수 : 19653

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 69566
# 등장 빈도가 6번 이하인 희귀 단어의 수: 47447
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 22119
# 단어 집합에서 희귀 단어의 비율: 68.20429520167897
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.4904191677526244

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[4033, 2284, 1825, 1446, 5187, 3979, 3196, 3595, 3516, 531, 490, 5983, 344, 5281, 285, 3952, 1446, 1142, 436, 1127, 338, 5187, 6534, 3308, 10, 1568, 5187, 1900, 6124, 4033, 1], [1612, 4971, 3106, 6621, 62, 1, 22, 625, 359, 36, 122, 8, 279, 5984, 205, 3106, 2913, 46, 15, 4306, 36, 434, 7090, 5496, 3025, 7355, 94, 4000, 286, 34, 2913, 1, 83, 1195, 204, 36, 434, 1341], [12, 275, 621, 1583, 2200, 19, 54, 374, 188, 291, 236, 5, 897, 105, 19, 1583, 92, 1583, 2200, 2440, 5, 74, 192, 616, 4394, 1315]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 40611
# 등장 빈도가 5번 이하인 희귀 단어의 수: 29350
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 11261
# 단어 집합에서 희귀 단어의 비율: 72.27105956514245
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 6.14376224858781

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 1985, 3, 16, 372, 336, 188], [1, 124, 7, 559, 354, 40, 1364, 563], [1, 187, 285, 1588, 123, 887], [1, 247, 309, 636, 5, 9, 65, 296, 7, 1299], [1, 271, 26, 5, 35, 115, 4, 667]]
# target
# decoder  [[1985, 3, 16, 372, 336, 188, 2], [124, 7, 559, 354, 40, 1364, 563, 2], [187, 285, 1588, 123, 887, 2], [247, 309, 636, 5, 9, 65, 296, 7, 1299, 2], [271, 26, 5, 35, 115, 4, 667, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 16
# 삭제할 테스트 데이터의 개수 : 6
# 훈련 데이터의 개수 : 78599
# 훈련 레이블의 개수 : 78599
# 테스트 데이터의 개수 : 19647
# 테스트 레이블의 개수 : 19647

# %%
#패딩하기
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=headlines_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=headlines_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=headlines_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=headlines_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)

# 인코더의 마지막 상태값을 디코더의 초기 상태로 전달
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 2000)   514000      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,633,104
# Trainable params: 3,633,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AdditiveAttent (None, None, 256)    256         lstm_3[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 2000)   1026000     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,145,360
# Trainable params: 4,145,360
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=20)
# Out:
# Epoch 1/20
# 308/308 [==============================] - 60s 80ms/step - loss: 3.4404 - val_loss: 3.1858
# Epoch 2/20
# 308/308 [==============================] - 24s 77ms/step - loss: 3.0312 - val_loss: 2.9248
# Epoch 3/20
# 308/308 [==============================] - 24s 79ms/step - loss: 2.7685 - val_loss: 2.7363
# Epoch 4/20
# 308/308 [==============================] - 25s 81ms/step - loss: 2.6124 - val_loss: 2.6289
# Epoch 5/20
# 308/308 [==============================] - 25s 83ms/step - loss: 2.4975 - val_loss: 2.5235
# Epoch 6/20
# 308/308 [==============================] - 26s 84ms/step - loss: 2.4030 - val_loss: 2.4440
# Epoch 7/20
# 308/308 [==============================] - 25s 82ms/step - loss: 2.3226 - val_loss: 2.4005
# Epoch 8/20
# 308/308 [==============================] - 26s 83ms/step - loss: 2.2517 - val_loss: 2.3409
# Epoch 9/20
# 308/308 [==============================] - 26s 83ms/step - loss: 2.1900 - val_loss: 2.3046
# Epoch 10/20
# 308/308 [==============================] - 26s 83ms/step - loss: 2.1358 - val_loss: 2.2757
# Epoch 11/20
# 308/308 [==============================] - 26s 83ms/step - loss: 2.0858 - val_loss: 2.2480
# Epoch 12/20
# 308/308 [==============================] - 26s 83ms/step - loss: 2.0420 - val_loss: 2.2298
# Epoch 13/20
# 308/308 [==============================] - 26s 83ms/step - loss: 2.0010 - val_loss: 2.2054
# Epoch 14/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.9636 - val_loss: 2.1897
# Epoch 15/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.9306 - val_loss: 2.1888
# Epoch 16/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.8996 - val_loss: 2.1730
# Epoch 17/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.8700 - val_loss: 2.1639
# Epoch 18/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.8423 - val_loss: 2.1606
# Epoch 19/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.8174 - val_loss: 2.1525
# Epoch 20/20
# 308/308 [==============================] - 26s 83ms/step - loss: 1.7930 - val_loss: 2.1576

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음
# Out:
# =3

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])#'encoder_outputs' is not defined

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (headlines_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2headlines(input_seq):
    temp_headlines =''
    for j in input_seq:
        if (j!=0) and tar_index_to_word[j] not in ('sostoken ', 'eostoken'):
            temp_headlines = temp_headlines+ tar_index_to_word[j]+' '
    return temp_headlines.strip()

# %%
# for i in range(50, 100):
#     print("원문 :", seq2text(encoder_input_test[i]))
#     print("실제 요약 :", seq2summary(decoder_input_test[i]))
#     print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
#     print("\n")

# 테스트 데이터 크기 확인
print("테스트 데이터 크기:", len(encoder_input_test))

# 유효한 범위에서만 루프 실행
for i in range(50, len(encoder_input_test)):  # 50부터 데이터 크기까지
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2headlines(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 테스트 데이터 크기: 19647
# 원문 : de former brazilian national team coach fired club monday brazilian tv channel reported sexually abused young boys channel presented testimony victims one anonymous victim claiming asked front
# 실제 요약 : sostoken former brazil coach accused of
# 예측 요약 :  coach resigns after being forced to
#
#
# 원문 : giant coca cola plans cut jobs cost cutting initiatives response slow sales company said tuesday job cuts clearly difficult impacted changes critical us company stated notably company reported fall net income year ago period
# 실제 요약 : sostoken to cut 1 200 jobs to
# 예측 요약 :  to cut off
#
#
# 원문 : indian army crossed line control killed three pakistani soldiers pakistani media reported quoting inter services public relations pakistani military media wing one pakistani soldier injured retaliation death four indian soldiers firing pakistani troops saturday reports said
# 실제 요약 : sostoken india killed 3 pakistani soldiers pak media
# 예측 요약 :  army kills indian in pakistan
#
#
# 원문 : many people killed two planes crashed swiss separate incidents within hours saturday passengers crew members died year old plane crashed metres sea level family four killed plane crashed near way france
# 실제 요약 : sostoken two planes crash in swiss in one day 24 killed
# 예측 요약 :  2 killed as plane crashes into in mumbai
#
#
# 원문 : mumbai witnessed nearly seven fold increase amount cocaine seized compared last year narcotics control bureau revealed kilograms cocaine seized till december year increased kilograms unlike movies one drug lord reality multiple players officials said
# 실제 요약 : sostoken increase in seized in mumbai in 2017
# 예측 요약 :  mumbai pune to get crore
#
#
# 원문 : australia chief selector mark confirmed contract ending august take role australia host world yet win tournament selection panel comes stepped coach amid ball tampering scandal replaced justin
# 실제 요약 : sostoken mark to quit as australian for job
# 예측 요약 :  australian captain to win for
#
#
# 원문 : nephew creator car used hollywood film franchise back future planning introducing upgrade car transform flying car aerospace company manufacture car suggests may powered electric motors liquid fuel
# 실제 요약 : sostoken team to develop flying car from to the films
# 예측 요약 :  car to
#
#
# 원문 : police conducted raid every two minutes average two years since bihar government imposed liquor ban average seven people arrested every hour act lakh arrests till march bihar excise act key promise cm nitish kumar election campaign
# 실제 요약 : sostoken every 2 mins in 2 yrs of bihar liquor ban
# 예측 요약 :  over 1 000 km in delhi
#
#
# 원문 : national green tribunal asked railways identify least model smart stations within two weeks tribunal also asked railway administration get water energy conducted within three months reduce use stations identified action plan may prepared within month said
# 실제 요약 : sostoken 36 stations in 2 weeks ngt to railways
# 예측 요약 :  ngt asks govt to check rail
#
#
# 원문 : global personal financial wealth grew touch trillion billionaires controlling almost half report boston consulting group said thursday controlled slightly less world total personal wealth us still number billionaires followed china
# 실제 요약 : sostoken now control half of the world's personal wealth
# 예측 요약 :  wealth rises to record
#
#
# 원문 : actress chawla revealed husband work adding could kiss co actor even go nude screen whatever script demands husband say anything added kind comfort level woman ask
# 실제 요약 : sostoken husband has no if i co star or go
# 예측 요약 :  i am not a woman actress
#
#
# 원문 : actor arjun kapoor took instagram share picture real madrid forward cristiano ronaldo wrote amazing feeling meeting talking football cristiano player guy actor met footballer madrid spain monday arjun signed spanish football league la liga promote india
# 실제 요약 : sostoken of a player arjun on pic with ronaldo
# 예측 요약 :  arjun shares pic with ronaldo
#
#
# 원문 : million sunday voted referendum held opposition president maduro plan constitution reports said comes amid months anti government protests nearly people died notably maduro campaigning form new assembly would constitution state institutions
# 실제 요약 : sostoken over 7 million vote in poll against president
# 예측 요약 :  prez orders of
#
#
# 원문 : reserve bank india monday said would crore system purchase government october amid fears potential credit central bank move comes government announced friday cut gross crore second half current fiscal
# 실제 요약 : sostoken rbi to 000 crore into system in
# 예측 요약 :  rbi to set up to ã¢ââ¹2 crore
#
#
# 원문 : dera sacha sauda thursday claimed human buried inside headquarters added chief gurmeet ram rahim encouraged followers donate remains prevent rivers causes pollution stated trees planted buried remains
# 실제 요약 : sostoken found are
# 예측 요약 :  in ram rahim
#
#
# 원문 : arbaaz khan confirmed third instalment franchise directed prabhu likely start shooting april need time work script pre production project said arbaaz earlier also said would like cast sunny leone film
# 실제 요약 : sostoken khan confirms will
# 예측 요약 :  to launch in
#
#
# 원문 : delhi chief minister arvind kejriwal monday reviewed plan setting sewage treatment plants locations currently access network according officials apart sewage crisis also produce water used water body non uses
# 실제 요약 : sostoken delhi govt to set up 600
# 예측 요약 :  delhi govt to set up to
#
#
# 원문 : england pacer mark wood part csk ongoing ipl along teammates sang danced cannot get enough praising look done tribute baahubali super ton words fail us seeing much csk wrote facebook
# 실제 요약 : sostoken creates for him with team
# 예측 요약 :  takes to mark trophy
#
#
# 원문 : first look poster richa chadha aditi rao rahul starrer dev released film also star anurag kashyap guest appearance modern take chandra novel directed mishra film scheduled release march
# 실제 요약 : sostoken first look poster of starrer out
# 예측 요약 :  first look poster of
#
#
# 원문 : death apple co founder steve jobs advised ceo tim cook never ask would right revealed cook apple memorial service jobs company campus year notably cook today seven years ceo world valuable company
# 실제 요약 : sostoken never ask what i'd do just do right jobs had told cook
# 예측 요약 :  apple steve jobs steve jobs
#
#
# 원문 : several people made videos man picked severed foot railway tracks haryana run train video shows man placing severed foot platform following offered support two people social media users slammed filming incident instead helping
# 실제 요약 : sostoken people film man up foot after train accident
# 예측 요약 :  video man found on train in up
#
#
# 원문 : denying rumours upcoming film manikarnika queen jhansi director kangana ranaut said true speak every day another release january could give dates added film kangana seen portraying rani lakshmi release january
# 실제 요약 : sostoken we daily kangana denies with maker
# 예측 요약 :  kangana denies kangana
#
#
# 원문 : television producer ekta kapoor called filmmaker karan johar father high school film said web series beat johar film student year since father right kuch kuch hota hai show please added ekta
# 실제 요약 : sostoken karan johar is father of high school film kapoor
# 예측 요약 :  sara denies reports of being
#
#
# 원문 : survived kilometre road trip australia car driver stopped heard animal wheel car parked fire brigade called take wheel order help wildlife rescue worker free animal
# 실제 요약 : sostoken 16 under car
# 예측 요약 :  driver car into
#
#
# 원문 : first ever flight self air aircraft conducted american brothers united states plane stayed air seconds covered nearly feet maiden flight notably born april
# 실제 요약 : sostoken first flight 12 feet
# 예측 요약 :  plane makes emergency landing after flight
#
#
# 원문 : occasion th birth anniversary kapoor sunday pooja bhatt tweeted never forget meeting saying father mahesh bhatt quit direction tell industry needs pooja wrote sure big wide mahesh decided come back passed away
# 실제 요약 : sostoken asked me why dad quit bhatt
# 예측 요약 :  i am to be a on my life
#
#
# 원문 : actress aishwarya rai bachchan recalling sudden engagement abhishek bachchan said south indians know added suddenly call house coming bachchan family arrived house aishwarya asked mother engagement like happened
# 실제 요약 : sostoken i didn't know what aishwarya on her
# 예측 요약 :  aishwarya is a abhishek
#
#
# 원문 : kannada actor vijay three got arrested sunday assaulting gym according complaint accused forcibly took gym maruti gowda outside event hall assaulted moving car denying assault vijay told police fans attacked abusing
# 실제 요약 : sostoken actor vijay gets arrested for assaulting
# 예측 요약 :  actor arrested for assaulting actress
#
#
# 원문 : youtuber rich completely damaged tesla cars puts back together without automaker help videos documents journey learn cars internal systems work repair floods first started working tesla cars buying second broken car repair parts
# 실제 요약 : sostoken tesla cars without help
# 예측 요약 :  tesla car cars in cars
#
#
# 원문 : india issued medical visa two half month old baby pakistan suffering heart disease father appealed external affairs minister sushma swaraj help see humanity despite many differences thank efforts humanity god everyone child father tweeted granted visa
# 실제 요약 : sostoken pak man tweets to swaraj about child gets visa
# 예측 요약 :  indian origin boy who saved baby
#
#
# 원문 : actress tanushree dutta accused actor nana patekar sexually harassing women child development minister maneka gandhi said also start something called india said india movement harassment complaints made women investigated added harassment kind
# 실제 요약 : sostoken we should start me too india says amid row
# 예측 요약 :  i am not a on sexual harassment
#
#
# 원문 : bjp president amit shah described congress counterpart rahul gandhi style politics pm narendra modi speech parliament talking bjp parliamentary party meeting parliamentary affairs minister kumar said details rafale deal already public added components affects national security
# 실제 요약 : sostoken rahul's of politics bjp prez amit shah
# 예측 요약 :  pm modi amit shah on rafale
#
#
# 원문 : union law minister ravi shankar prasad said former prime minister manmohan singh speech terming demonetisation organised seen manmohan singh work years words prasad said incidents stone pelting declined kashmir naxal activities due demonetisation prasad added
# 실제 요약 : sostoken speech on was
# 예측 요약 :  no of gandhi singh
#
#
# 원문 : new zealand prime minister tuesday announced post minister arms control amid tensions asia pacific region due north korea nuclear programme portfolio focus nuclear chemical conventional weapons deputy pm foreign affairs minister appointed post
# 실제 요약 : sostoken nz minister post amid n korea threat
# 예측 요약 :  new zealand to be held for
#
#
# 원문 : khan became first pakistani batsman th overall score test runs reaching landmark first test west indies sunday year old made debut took tests total also became oldest cricketer reach landmark
# 실제 요약 : sostoken first pakistani batsman to score 10 000 test runs
# 예측 요약 :  becomes 1st batsman to score 100 in a test
#
#
# 원문 : samajwadi party bahujan samaj party announced alliance union law minister ravi shankar prasad saturday said sp bsp alliance survival interest country uttar pradesh added said opposition pm narendra modi sole basis alliance
# 실제 요약 : sostoken sp alliance is for their
# 예측 요약 :  sp alliance with sp sp chief
#
#
# 원문 : google recent event confirmed dark mode android phones uses less power battery life affects battery life white colour drawing power company said google also showed dark mode use less power full normal mode youtube app
# 실제 요약 : sostoken google confirms on android life
# 예측 요약 :  google to help users to protect
#
#
# 원문 : filmmaker philip claimed google used seconds footage seven videos internal video leaked last week without permission added contacted google said video internal use offered compensation google said executive made video strict copyright rules
# 실제 요약 : sostoken accuses google of using his videos in leaked
# 예측 요약 :  google to send to
#
#
# 원문 : prime minister narendra modi met farmer narayan singh chauhan uttar pradesh wrote foot long handwritten letter singh two points letter first policies prime minister impact lives people second districts feel
# 실제 요약 : sostoken pm modi meets who foot letter to him
# 예측 요약 :  pm modi meets his feet
#
#
# 원문 : one week old girl succumbed injuries today suffering injuries fire hospital andheri taking death toll condition twin brother said stable notably inquiry ordered following level four fire hospital recently denied final objection certificate
# 실제 요약 : sostoken 1 week old girl to in hospital fire
# 예측 요약 :  16 year old girl dies after being hit by in noida
#
#
# 원문 : fc barcelona players wear special shirts barcelona written back instead names tribute victims thursday terror attack city front shirts players also wear black team opening league game season
# 실제 요약 : sostoken to feature message as tribute to terror victims
# 예측 요약 :  players wear to wear at event
#
#
# 원문 : italian forward took instagram share video scoring shot behind goal training challenged brazilian defender year old forward also tagged players including neymar paul former manchester city forward scored goals international matches
# 실제 요약 : sostoken player scores from behind goal
# 예측 요약 :  video shows shot dead in mexico
#
#
# 원문 : former cricketer sachin tendulkar attended wedding ceremony cricketer krunal pandya girlfriend sharma wednesday actor amitabh bachchan mumbai indians owner mukesh ambani also cricketer reception earlier videos emerged showing krunal brother india rounder hardik dancing pre wedding functions
# 실제 요약 : sostoken sachin tendulkar wedding in mumbai
# 예측 요약 :  sachin attend wedding with
#
#
# 원문 : pm narendra modi said despite congress aware rupee reached rule party nothing stop corruption must heard ex prime minister talking corruption added notably rajiv gandhi said paise every rupee meant welfare reached people
# 실제 요약 : sostoken cong allowed only of a to reach people pm
# 예측 요약 :  pm modi on corruption
#
#
# 원문 : union minister singh wednesday took dig aimim chief asaduddin owaisi comment noida police order barring open saying owaisi talking pakistani pm imran khan language added law equal everyone owaisi said police mean peace
# 실제 요약 : sostoken in pak pm imran khan's language singh
# 예측 요약 :  don't make to
#
#
# 원문 : billionaire investor world fourth richest person warren buffett made annual summer donation berkshire stock worth billion charity sum buffett biggest ever summer donation last year billion gift record donation due rising value berkshire share price past year
# 실제 요약 : sostoken billionaire breaks own record donates ã¢ââ¹20 400 crore
# 예측 요약 :  billionaire breaks worth 100 billion
#
#
# 원문 : actress sonam kapoor took instagram share picture cousin janhvi kapoor st birthday celebrations kapoor daughters wrote photo caption janhvi half sister hosted dinner residence attended family members close friends mark janhvi birthday
# 실제 요약 : sostoken sonam shares pic from birthday
# 예측 요약 :  sonam shares pic with ranbir from her
#
#
# 원문 : nia special court issued non bailable warrants mumbai attack mastermind hafiz saeed hizbul mujahideen chief syed involvement terror funding activities jammu kashmir pakistan trained terrorists pushed india war india design india agency said
# 실제 요약 : sostoken court issues non against
# 예측 요약 :  pak court orders forces to terror attacks
#
#
# 원문 : union steel minister chaudhary singh friday said joint venture steel authority india signed soon technology keen added said proposed crore steel plant come andhra pradesh
# 실제 요약 : sostoken joint between soon minister
# 예측 요약 :  india to be by
#
#
# 원문 : man shared images former indian pm manmohan singh bangladesh pm sheikh among others sentenced seven years prison bangladesh accused shared images mobile phones users also fined bangladeshi
# 실제 요약 : sostoken b'desh man jailed over pics of singh others
# 예측 요약 :  man who to jail for indian
#
#
# 원문 : seven year old boy district jammu kashmir earned praise australian spin legend shane warne video bowling surfaced online warne retweeted video wrote outstanding well bowled young man journalist originally posted video said ball turned metre half
# 실제 요약 : sostoken praises 7 yr old calls it
# 예측 요약 :  yr old j k boy to be beaten up for
#
#
# 원문 : responding rti query external affairs ministry said received request extradition deportation return dawood ibrahim hafiz saeed query asked action taken government bring two back india ibrahim saeed main accused mumbai terror attacks respectively
# 실제 요약 : sostoken no for rti
# 예측 요약 :  i am not a security director
#
#
# 원문 : name english william different ways including records lifetime name william due proper april considered birth date
# 실제 요약 : sostoken name was in over 80 during his life
# 예측 요약 :  man who award for
#
#
# 원문 : logo amitabh bachchan aamir khan katrina kaif fatima sana shaikh starrer thugs hindostan unveiled directed vijay krishna acharya film scheduled release november period drama based philip taylor novel produced yash raj films
# 실제 요약 : sostoken of amitabh aamir starrer of unveiled
# 예측 요약 :  big b katrina to star in film
#
#
# 원문 : australian captain steve smith scored rd test ton help side secure draw england fourth test melbourne saturday captains agreed settle match drawn shortly smith completed ton final day former england captain cook carried bat score record unbeaten
# 실제 요약 : sostoken test ton helps australia draw 4th test
# 예측 요약 :  smith steve smith to reach their 1st time in t20i
#
#
# 원문 : fuel tanker explosion resulting collision near airport northern italy captured camera least people killed others injured explosion blast area flames black smoke caused bridge partially collapse
# 실제 요약 : sostoken fuel caught on camera in italy
# 예측 요약 :  2 planes into plane in
#
#
# 원문 : pm narendra modi celebrated diwali jawans indian army bsf jammu kashmir thursday pm modi said like everyone else wished spend diwali family visited jawans considers family also said happy know jawans practice yoga regularly
# 실제 요약 : sostoken pm modi celebrates diwali in j k calls jawans
# 예측 요약 :  pm modi meets pm modi for
#
#
# 원문 : case registered former himachal pradesh chief minister singh son allegedly breaking historical structure belonging relative family dispute complainant nephew rajkumar singh alleged portion palace forcibly captured former himachal pradesh cm several others
# 실제 요약 : sostoken ex himachal cm booked for into property
# 예측 요약 :  ex himachal cm's son booked for
#
#
# 원문 : man fifties arrested delhi airport making woman later found cisf constable approached constable started later made incident taken place june midnight punjab man travelling new york
# 실제 요약 : sostoken man makes at woman later finds she is a cop
# 예측 요약 :  man arrested for woman into delhi airport
#
#
# 원문 : viral video rally muslim community allegedly seeking release man accused raping year old girl madhya pradesh found fake according fake video protestors sought release claiming sanctions rape non muslim women shown rally read release irfan
# 실제 요약 : sostoken video of muslims seeking release of rape accused fake
# 예측 요약 :  video shows fake man who live in tn
#
#
# 원문 : us bank chase ceo said would fire second employee trading bitcoin stupid said cryptocurrency end well called fraud drug stuff like better bitcoin us dollars added
# 실제 요약 : sostoken will fire employees who on bitcoin ceo
# 예측 요약 :  we are of us ceo
#
#
# 원문 : delhi high court friday ruled barring recruitment women territorial army fundamental rights provided constitution court observed hearing plea claiming rule discrimination territorial army india second line defence regular army expected assist natural disasters
# 실제 요약 : sostoken women from army hc
# 예측 요약 :  delhi hc to women on women
#
#
# 원문 : bridges different parts country collapse need immediate attention road transport highways minister nitin gadkari revealed parliament thursday information came light ministry completed safety audit lakh bridges india gadkari added road projects worth lakh crore facing delays
# 실제 요약 : sostoken 100 can min gadkari
# 예측 요약 :  govt asks to help mps in
#
#
# 원문 : president donald trump threatened withdraw us world trade organisation shape claiming country badly added agreement establish single worst trade deal ever made trump repeatedly claimed unfair us global trade
# 실제 요약 : sostoken trump threatens to us from world trade
# 예측 요약 :  us trade war would be world trade
#
#
# 원문 : rights global television digital release man film delhi chief minister arvind kejriwal acquired us media company vice film non fiction political thriller rise kejriwal social activist politician film scheduled release november
# 실제 요약 : sostoken us media company to release film on kejriwal
# 예측 요약 :  kamal haasan to remove from
#
#
# 원문 : two men woman including suspected killer found dead home us state texas friday officials said two others found dead home one home victims authorities claimed believed two incidents connected
# 실제 요약 : sostoken 5 found dead in to home shooting
# 예측 요약 :  woman found dead in
#
#
# 원문 : teacher ratio government schools improved significantly economic survey revealed monday apart student ratio also improved survey showed schools also seen improvement areas like levels completion rates drinking water facilities toilet facilities survey revealed
# 실제 요약 : sostoken govt teacher economic survey
# 예측 요약 :  students to get school in
#
#
# 원문 : microsoft let users protect certain files ransomware attack upcoming windows update tool allows specific apps access users app attempts make changes protected files update comes windows computer systems around world hit ransomware like wannacry
# 실제 요약 : sostoken 10 to protect files from
# 예측 요약 :  microsoft to use to track
#
#
# 원문 : class th student allegedly attacked teacher iron rod getting attendance school delhi teacher found rod boy bag kept table boy took back used attack confronted
# 실제 요약 : sostoken delhi boy attacks teacher with after being
# 예측 요약 :  class 10 student beaten to teacher in school
#
#
# 원문 : former world number one andy murray withdrew going washington open ahead match breaking tears post finish pre match three time grand slam champion cited reason behind withdrawal murray said finishing matches three morning good anyone
# 실제 요약 : sostoken ex world no 1 withdraws from c'ship after 3 am win
# 예측 요약 :  world no 1 in a world c'ship
#
#
# 원문 : bihar government thursday revoked earlier order withdrew state military police jawans posted outside former cm devi residence claimed government conspiring get killed demanding clarification issued initial order withdraw security son tejashwi yadav called bihar cm nitish kumar ram
# 실제 요약 : sostoken bihar govt order security for
# 예측 요약 :  bihar cm orders to
#
#
# 원문 : four sitting senior supreme court judges friday directly addressed media first time claiming chief justice dipak misra failed address concerns regarding administration apex court also released two month old letter cji misra wherein accused cases without basis
# 실제 요약 : sostoken sc media for first time
# 예측 요약 :  sc judge on cji
#
#
# 원문 : four children khan lynched mob alwar suspicion cow provided free education run ex vice president hamid ansari wife reportedly school steps foundation take care hostel fees children
# 실제 요약 : sostoken kids to get free education in
# 예측 요약 :  women beaten up to stop cow in wb
#
#
# 원문 : born august vikram founded isro launch india first satellite dr dialogue nasa resulted launch satellite television experiment bringing cable television rural india mentor late president abdul kalam late padma awardee also co founded ahmedabad
# 실제 요약 : sostoken isro founder had tv to india
# 예측 요약 :  isro launches satellite for the first time
#
#
# 원문 : american couple finally removed alarm clock stuck inside wall years story made clock daily tied dropped air broke leaving stuck couple said used clock
# 실제 요약 : sostoken couple removes stuck that was daily for 13 yrs
# 예측 요약 :  couple remove from in uk
#
#
# 원문 : indian origin man sentenced months prison uk posting anti muslim tweets including one claimed wanted slit muslim throat chand posted series anti muslim tweets wake manchester attack police said charged publishing material intended racial hatred
# 실제 요약 : sostoken indian origin man gets 20 month jail over anti muslim tweets
# 예측 요약 :  indian origin man jailed for muslim
#
#
# 원문 : kartik made debut ka said like anti hero zone love watching would like something comedy offered lot comedy films want serious films added kartik said comedy difficult thing
# 실제 요약 : sostoken want to do other than now
# 예측 요약 :  love love to love love
#
#
# 원문 : uk based mobile network operator company mobile slammed user twitter made joke company micro site later user replied mobile tweet phone company posted man starts man notably mobile earlier slammed another user tweeted services
# 실제 요약 : sostoken uk phone company hits back at troll on twitter
# 예측 요약 :  app uses to users
#
#
# 원문 : phd student university lucknow managed teach subject required paper conduct examination also answer books matter came light deputy examination marks vice chancellor later ordered cancellation student phd programme
# 실제 요약 : sostoken student caught self his own
# 예측 요약 :  student for paper in
#
#
# 원문 : supreme court friday asked central pollution control board difference ban sale firecrackers made pollution delhi ncr court asked file report know whether pollution region post ban apex court banned firecrackers sale delhi ncr october november
# 실제 요약 : sostoken how did ban delhi pollution sc asks
# 예측 요약 :  sc asks delhi to ban on
#
#
# 원문 : late actress banerjee boyfriend rahul raj singh filed police complaint punjabi accusing tampering old video earlier tweeted teaser short film featuring trying make money name dead person make short film relationship said rahul
# 실제 요약 : sostoken boyfriend files police complaint against
# 예측 요약 :  rahul booked for assaulting
#
#
# 원문 : government tuesday said decided lakh companies various non crackdown shell companies earlier nearly lakh companies lakh directors associated disqualified around cases filed national company law tribunal restoration companies government added
# 실제 요약 : sostoken govt to 1 more firms in firm
# 예측 요약 :  govt to companies to firms
#
#
# 원문 : indian batsman kl rahul got tattoo pet dog back batsman posted photo tattoo facebook caption read guess got back karnataka batsman often shared photos pet dog written loves spending time
# 실제 요약 : sostoken rahul gets on his back
# 예측 요약 :  rahul shares pic with fan
#
#
# 원문 : sri lanka chased india thursday record highest successful chase champions trophy history also sri lanka joint highest successful chase odis chased england notably first time india failed defend plus team total icc tournament match
# 실제 요약 : sostoken sl defeat india to highest in champions trophy
# 예측 요약 :  india record their most ever in t20i
#
#
# 원문 : two prisoners escaped maximum security jail capital getting guard drunk let go purchase alcohol authorities said guard reportedly alcohol refused undergo breath test meanwhile police currently looking prisoners
# 실제 요약 : sostoken get guard drunk and prison in
# 예측 요약 :  two men get drunk cars in
#
#
# 원문 : scottish championship st united witnessed fight opposing fans earlier fans warned day game may postponed due weather conditions one point aimed media box st former manager former player
# 실제 요약 : sostoken football game fight between fans
# 예측 요약 :  fans fans after fans
#
#
# 원문 : year old girl army vehicle south kashmir thursday police said farooq hit injured army vehicle near residence morning official said protests erupted area succumbed injuries taken hospital
# 실제 요약 : sostoken 12 year old girl down by army vehicle in kashmir
# 예측 요약 :  16 year old girl killed in j k
#
#
# 원문 : british banks handled nearly million russian criminals links russian government according guardian also named banks including probed illegal money transfers reportedly billion moved russia
# 실제 요약 : sostoken british banks mn of russian money
# 예측 요약 :  uk sanctions over of
#
#
# 원문 : following surge milk prices russia due president vladimir putin ban eu cheese imports french maker almost cows ensure affordable supply milk prices going head russian unit said adding puts products pressure
# 실제 요약 : sostoken sends cows to in search for
# 예측 요약 :  russia to ban on
#
#
# 원문 : year old pregnant woman karnataka died due lack doctors rural hospital labour woman family alleged nurse started delivery procedure doctor call family also said allowed shift another hospital even critical
# 실제 요약 : sostoken pregnant woman dies due to of doctors at hospital
# 예측 요약 :  woman dies after being denied by
#
#
# 원문 : us friday asked china immediately release th lama reportedly abducted country age six recognised dalai lama th lama lama responsible recognition dalai lama
# 실제 요약 : sostoken us asks china to release
# 예측 요약 :  china to be in
#
#
# 원문 : taking part protests centre delay setting cauvery management board actor rajinikanth said time ipl chennai scheduled ipl matches cannot cancelled chennai super kings players wear black highlight farmers facing water shortage tamil nadu rajinikanth added
# 실제 요약 : sostoken time not for ipl in chennai on dispute
# 예측 요약 :  ipl in delhi
#
#
# 원문 : russia blocked access chinese social media app failing give contact details country communications watchdog access china popular social media platform reportedly restricted since thursday last year russia blocked us social networking site violating law requires data russian citizens stored russian servers
# 실제 요약 : sostoken russia blocks chinese social media app
# 예측 요약 :  russia to us over security
#
#
# 원문 : wwe paul manager criticised icc eat sleep repeat praising india wicketkeeper batsman ms dhoni icc official world cup account tweeted image dhoni caption eat sleep finish games repeat life ms dhoni may paid cash check stock cryptocurrency wrote
# 실제 요약 : sostoken icc for his for dhoni
# 예측 요약 :  ms dhoni is ms dhoni's
#
#
# 원문 : following consumer complaints telecom regulator trai directed aircel refund balance subscribers security deposit subscribers regulator also asked submit area wise compliance report may notably aircel filed bankruptcy february year citing intense competition sector
# 실제 요약 : sostoken to to
# 예측 요약 :  to be by
#
#
# 원문 : ex manchester united striker scored goal nearly six minutes debut la galaxy la fc followed th minute goal injury time helped la galaxy beat la fc heard crowd saying want gave later said
# 실제 요약 : sostoken scores 40 goal 6 minutes into debut for new team
# 예측 요약 :  scores goal in a goal
#
#
# 원문 : government seeking form panels monitor functions rbi according reports government reportedly recommended rbi board draft regulations set monitor functions financial stability foreign exchange management panel might two three members central bank board reports added
# 실제 요약 : sostoken government wants to rbi reports
# 예측 요약 :  govt to set up panel to file reports
#
#
# 원문 : asked relationship advice would give ranbir kapoor ranveer singh said ranbir person seen life need advice anyone else talking working ranbir ranveer said would love ranbir one favourite actors experience
# 실제 요약 : sostoken ranbir has seen life doesn't need relationship ranveer
# 예측 요약 :  ranbir is the ranbir
#
#
# 원문 : stating implementation gst problem former rbi governor raghuram rajan said would give hope point nice could implement much better work said addressing students harvard school rajan also reiterated demonetisation good idea
# 실제 요약 : sostoken give up hope on gst at this
# 예측 요약 :  i don't think of the gst
#
#
# 원문 : absconding businessman liquor baron vijay mallya granted bail tuesday till december said media court proceedings denied allegations made continue deny former kingfisher airlines chief said enough evidence prove case added
# 실제 요약 : sostoken not to media mallya after being bail
# 예측 요약 :  vijay mallya to be in case
#
#
# 원문 : new zealand martin went unsold ipl auction slammed ball ton australia register fastest ton nation former new zealand captain mccullum ball record also went past former captain record runs become highest run scorer cricket
# 실제 요약 : sostoken at ipl auction player slams fastest t20i ton for nz
# 예측 요약 :  nz player takes to take 1 in a test
#
#
# 원문 : mcdonald south west india operator restaurants said stopped use plastic outlets switched wooden paper move non plastic able reduce tonnes plastic per year company spokesperson said mcdonald restaurants across west south india
# 실제 요약 : sostoken mcdonald's stops use of plastic in west south india
# 예측 요약 :  mcdonald's to use plastic to
#
#
# 원문 : elon musk led spacex launch enterprise computer international space station august launch part joint experiment nasa test high performance hardware survive outer space conditions although hardware modified team built conditions space
# 실제 요약 : sostoken spacex to send to international space station
# 예측 요약 :  spacex to launch new space for the first time
#
#
# 원문 : actor tiger shroff said brother kind person wants sister added know saying people say oh sexist called names care tiger sister krishna shroff three years younger
# 실제 요약 : sostoken i'm want to my sister in tiger
# 예측 요약 :  i am not to be a man tiger on
#
#
# 원문 : expressing hope instant triple talaq bill passed rajya sabha soon president ram nath kovind monday said dignity honour muslim women held hostage decades honour muslim women decades tied political gains losses nation opportunity release said
# 실제 요약 : sostoken muslim women's held for prez kovind
# 예측 요약 :  triple talaq bill kovind
#
#
# 원문 : richard conducted ipl since first edition revealed bcci fired one line email email read services required chosen replacement revealed added bcci give reason thank years service
# 실제 요약 : sostoken bcci fired me via 1 line man who all ipl
# 예측 요약 :  ipl final to be
#
#
# 원문 : telangana government released new music video celebrate nine day festival began wednesday video mp seen along television anchor celebrating festival notably state government recently began free distribution one crore women poverty line occasion
# 실제 요약 : sostoken telangana government releases music video on
# 예측 요약 :  telangana cm shares video of
#
#
# 원문 : mumbai police decided screen four short films cinema halls across city spread awareness among people films talk measures cyber fraud urge people share bank details debit credit card numbers videos also uploaded social media platforms
# 실제 요약 : sostoken mumbai theatres to screen 4 short films on
# 예측 요약 :  mumbai police to promote
#
#
# 원문 : around lakh indians participated nation poll said satisfied current government around believe corporate frauds feel change feel internal affecting harmony increased feel change
# 실제 요약 : sostoken with the government of the nation poll
# 예측 요약 :  over lakh
#
#
# 원문 : healthcare home services run organisations like care family member offering senior citizens free people pay someone come talk place read evening go like said senior citizen
# 실제 요약 : sostoken service offers to senior citizens for free
# 예측 요약 :  to offer to offer
#
#
# 원문 : ahead final draft national register citizens home minister rajnath singh said individuals assam get sufficient opportunity prove citizenship series tweets said final nrc published objections examined adding nobody placed detention nrc
# 실제 요약 : sostoken people will be allowed to in assam govt
# 예측 요약 :  assam govt praises rajnath
#
#
# 원문 : european commission may reportedly fine google billion abusing android mobile operating system eu began case accusing google imposing illegal terms android device makers harm competition earlier google fined billion abusing search give advantage shopping comparison service
# 실제 요약 : sostoken google may face fine for via android
# 예측 요약 :  eu to buy google store over
#
#
# 원문 : national human rights commission monday issued notice uttar pradesh government following death least people consumed alcohol alcohol purchased shops kanpur nagar kanpur districts reports said excise department launched probe three people arrested case
# 실제 요약 : sostoken notice to up as 11 killed after having alcohol
# 예측 요약 :  ias officers in uttar pradesh
#
#
# 원문 : finance ministry said direct tax gdp ratio achieved best years added growth number returns filed last four financial years larger purpose demonetisation move india tax society ministry said
# 실제 요약 : sostoken tax to of 5 in best in 10 years govt
# 예측 요약 :  gst rate in 2016 17
#
#
# 원문 : year study lakh danish women found forms carry added risk breast cancer five years women stop taking study account lifestyle alcohol consumption researchers suggested use non like condoms instead birth control
# 실제 요약 : sostoken study birth control to cancer
# 예측 요약 :  women study
#
#
# 원문 : russian president vladimir putin said first name terms us president donald trump adding relations among world leaders russian president praised trump referring us market growth putin said claims russian meddling us presidential election trump enemies
# 실제 요약 : sostoken donald and i are on first name russia prez putin
# 예측 요약 :  putin president putin
#
#
# 원문 : several accounts name paytm girl surfaced different social media platforms including instagram primarily focused offer sex services accounts reportedly provide variety remote sexual services exchange payments digital wallet paytm accounts even accepting payments flipkart app
# 실제 요약 : sostoken accounts named sex online
# 예측 요약 :  fb to pay to parents for
#
#
# 원문 : raveena tandon slammed media house publishing report fir filed allegedly shooting advertisement inside temple open eyes wake look around get facts right tweeted earlier official advertising agency clarified shooting temple premises
# 실제 요약 : sostoken slams media house over report on fir against her
# 예측 요약 :  media files fir against over pics
#
#
# 원문 : pacer jasprit bumrah missed dismissing england captain joe root th test india appeal revealed ball ball bumrah later showed ball would gone hit leg stump bumrah cost india pakistan batsman wicket champions trophy final
# 실제 요약 : sostoken due to an no ball
# 예측 요약 :  takes one handed catch to
#
#
# 원문 : maker food services reportedly raised million funding led existing investor belgium based investment holding company billion assets across globe october food raised million series round capital
# 실제 요약 : sostoken food services raises crore in funding
# 예측 요약 :  food delivery startup raises crore
#
#
# 원문 : pictures baahubali actor prabhas wax statue madame tussauds bangkok surfaced online prabhas first south indian actor whose wax statue featured madame tussauds reports claimed artists took least photographs actor create wax statue
# 실제 요약 : sostoken pics of baahubali actor statue online
# 예측 요약 :  katrina shares statue of statue at delhi
#
#
# 원문 : tesla ceo elon musk shared email driver involved tesla car crash admitted vehicle system engaged comes driver told police car suddenly engaging system crashed tesla shares news crash
# 실제 요약 : sostoken driver in tesla car admits he wasn't using
# 예측 요약 :  tesla car car in car crash
#
#
# 원문 : bse chairman ravi booked case former aircel promoter companies allegedly defrauding bank crore ravi independent director chairman audit committee bank cbi named bank officials worked senior levels loans sanctioned firms
# 실제 요약 : sostoken chairman s named in cr loan fraud case
# 예측 요약 :  cbi files against former director
#
#
# 원문 : air india federation indian airlines shiv sena mp ravindra gaikwad air carrier indigo member cancelled delhi pune return ticket gaikwad hit ai staffer booked indigo flight agent friday ai cancelled return ticket pm flight
# 실제 요약 : sostoken indigo cancels shiv sena mp return flight ticket
# 예측 요약 :  air india shiv sena mp over
#
#
# 원문 : former cia agent wilson launched campaign raise billion buy twitter ban president donald trump platform trump done lot things twitter white promoting violence threatening nuclear war north korea takes dangerous new level campaign page read
# 실제 요약 : sostoken former seeks to buy twitter and ban donald trump
# 예측 요약 :  ex google launches trump's
#
#
# 원문 : bengaluru based energy raised million dutch development bank us government agency overseas private investment corporation african finance institution germany development finance institution also participated funding round founded energy provides solar energy solutions residential commercial purposes
# 실제 요약 : sostoken solar maker raises 15 million
# 예측 요약 :  raises crore from
#
#
# 원문 : asserting life danger bsp leader mukhtar ansari thursday accused union minister manoj sinha wanting get killed life threat transferred lucknow district jail jail added notably ansari prison since murder charges
# 실제 요약 : sostoken minister sinha to kill me
# 예측 요약 :  will be in jail if they kill
#
#
# 원문 : owner manager indian restaurant britain found guilty delivering food teenage girl died effects teenager time suffered reaction ordering restaurant suffered brain damage died
# 실제 요약 : sostoken indian restaurant owner in uk convicted over 15 year death
# 예측 요약 :  hong kong man who saved from
#
#
# 원문 : talking playing lead biopic shiv sena founder bal thackeray actor nawazuddin siddiqui said think actor would agreed play role nawazuddin added think life shown three hours suggested late leader life shown web series many episodes
# 실제 요약 : sostoken any actor to play nawazuddin
# 예측 요약 :  i am not playing role in
#
#
# 원문 : accounting total crimes committed country uttar pradesh recorded highest number violent crimes murder crimes women according national crime records bureau state reported highest number murders registered total cases crimes women
# 실제 요약 : sostoken uttar pradesh records highest number of in 2016
# 예측 요약 :  over 100 000 people in j k
#
#
# 원문 : australian pacer mitchell played virat kohli captaincy royal challengers bangalore ipl said played couple virat fantastic play captain obviously fantastic player way india play series go cricket added
# 실제 요약 : sostoken virat kohli has been to play under
# 예측 요약 :  virat kohli for award
#
#
# 원문 : celebrities attending year golden globe awards seen wearing black sign victims sexual assault harassment following allegations top hollywood actors filmmakers celebrities also seen sporting campaigns like time aim fight harassment gender entertainment industry
# 실제 요약 : sostoken dress in black after sexual abuse row
# 예측 요약 :  awards to protest victims
#
#
# 원문 : china thursday started operating world fastest bullet train beijing shanghai country route train average speed km hr maximum speed km hr cover kilometres distance hours minutes notably country reduced train speeds collision killed people
# 실제 요약 : sostoken china gets the world's fastest bullet train
# 예측 요약 :  china to train station in
#
#
# 원문 : afghanistan thursday accused pakistan carrying cross border air strikes caused damage province calling air strikes violation international norms afghan foreign ministry warned pakistan acts would consequences bilateral ties came ahead pakistan pm shahid abbasi visit afghanistan
# 실제 요약 : sostoken afghanistan accuses pakistan of cross border air strikes
# 예측 요약 :  pakistan to air air strikes
#
#
# 원문 : former finance minister chidambaram thursday compared new aadhaar virtual id safety measure stable millions persons already shared aadhaar number many service providers added unique identification authority india announced new safety measures following report data breach
# 실제 요약 : sostoken after chidambaram on aadhaar
# 예측 요약 :  former rbi chidambaram
#
#
# 원문 : bengaluru based wealth management startup raised million series funding round led us based capital round also saw participation existing investor capital founded anand iyer startup users making decisions financial investment planning
# 실제 요약 : sostoken wealth startup raises 3 8 mn in series b
# 예측 요약 :  startup raises crore from others
#
#
# 원문 : japanese billionaire selected spacex first private passenger fly around moon said would like invite six eight artists around world trip asked create something return earth within us art collector added
# 실제 요약 : sostoken japanese billionaire to take 8 with him to the moon
# 예측 요약 :  billionaire to fly 1st moon landing in
#
#
# 원문 : woman shared chat author chetan bhagat trying bhagat said better judgement felt kind connection stupid feel way said bhagat sorry person concerned added
# 실제 요약 : sostoken i the on harassment
# 예측 요약 :  woman claims she was to
#
#
# 원문 : defeated bjp bypolls shiv sena saturday accused party opposition voice using money power possible corrupt means used win elections editorial party read alleged bjp members parties win civic elections
# 실제 요약 : sostoken power money used to shiv sena
# 예측 요약 :  bjp won of in power
#
#
# 원문 : goods services tax council decided human hair tax requested centre purchases making gst trust accounts department earlier estimated annual additional burden crore gst imposition
# 실제 요약 : sostoken human hair under gst at temple
# 예측 요약 :  tax to gst
#
#
# 원문 : fully loaded gb ram gb storage available flipkart combination ai engine gb ram make performance featuring dual cameras dual technology times puts best value money flagship phone market
# 실제 요약 : sostoken ram now on flipkart
# 예측 요약 :  to build in
#
#
# 원문 : italian automaker ferrari launched ferrari delhi ex india price crore powered engine car go kmph seconds achieve top speed kmph upgrade california made debut ferrari th anniversary celebration last year italy
# 실제 요약 : sostoken launched in india at ã¢ââ¹3 5 crore
# 예측 요약 :  india to buy crore in
#
#
# 원문 : platform said million donations campaign raise billion us president donald trump wall border mexico fell short goal brian launched campaign said created florida based non profit named build wall take contributions
# 실제 요약 : sostoken to 20 million for trump's border wall
# 예측 요약 :  raises crore in mexico
#
#
# 원문 : according regulatory filing reliance jio planning raise crore rights issue shares fixed income securities turned certain number shares common stock period take total investment reliance industries telecom arm lakh crore
# 실제 요약 : sostoken reliance jio to raise ã¢ââ¹20 000 crore through rights issue
# 예측 요약 :  reliance jio to raise crore to
#
#
# 원문 : chief economic advisor arvind subramanian friday hailed india rating upgrade moody saying long said recognition actions government undertaken gst bankruptcy moody friday india rating changed stable positive
# 실제 요약 : sostoken long
# 예측 요약 :  india is a
#
#
# 원문 : day urjit patel resigned rbi governor niti aayog vice chairman rajiv kumar said rbi particular individual rbi institutional capabilities strong whatever required markets economy kumar added also said patel done amazing work governor
# 실제 요약 : sostoken rbi not on one person after exit
# 예측 요약 :  rbi governor quits as rbi governor
#
#
# 원문 : congress leader digvijaya singh sunday asked actor anupam kher would change views bjp mp yogi adityanath remark came adityanath declared cm earlier event anupam said people like yogi adityanath speak thrown bjp put behind bars
# 실제 요약 : sostoken will change his on adityanath
# 예측 요약 :  bjp leaders to send to bjp
#
#
# 원문 : actor sanjay dutt said next film munna bhai series lines munna bhai america cannot get american visa sanjay added third film franchise said going right film
# 실제 요약 : sostoken no as i can't get us visa sanjay
# 예측 요약 :  dutt in sanjay dutt
#
#
# 원문 : aamir khan wasim starrer secret superstar beaten opening day collections dangal china earning crore dangal first indian film china cross collections crore making highest grossing non hollywood film country secret superstar released india october last year
# 실제 요약 : sostoken secret beats 1st day in china
# 예측 요약 :  aamir khan's in china
#
#
# 원문 : bengaluru based online buy sell platform raised around crore venture debt backed capital last raised crore debt financing brand capital august founded thomas company counts tiger global management partners india network among investors
# 실제 요약 : sostoken bengaluru e raises crore from
# 예측 요약 :  raises crore from debt
#
#
# 원문 : united airlines flight attendant leaked cockpit access codes information public website pilot claimed united said working action air line pilots association said error fixed cockpit access codes would allow anyone access cockpit aircraft although pilots could block entrance
# 실제 요약 : sostoken united airlines employee access online
# 예측 요약 :  airlines airlines to get flights from
#
#
# ...
# 실제 요약 : sostoken bcci shares video of indian captain virat kohli working out
# 예측 요약 :  bcci to virat kohli for
#
#
# 원문 : announced first bug bounty program offering lakh hackers find partnership bug bounty platform says launch disclosure scheme part program hackers earn lakh per bug
# 실제 요약 : sostoken to pay hackers up to ã¢ââ¹7 lakh to find in its
# 예측 요약 :  bug that bug worth ã¢ââ¹2 lakh
#
#
# 원문 : sharing old picture shah rukh khan instagram seen gym filmmaker karan johar wrote srk tried level best train johar fitness kunal earlier revealed filmmaker lost kilograms months post birth twins
# 실제 요약 : sostoken when srk tried his level best to train me johar on old pic
# 예측 요약 :  srk for srk with karan
#
#
# 원문 : union minister nitin gadkari wednesday flagged india first taxi ambulance services delhi service gurugram based startup cab cabs equipped medical supplies trained drivers drivers approach accident victims soon notified get additional every victim
# 실제 요약 : sostoken 1st taxi service off in delhi
# 예측 요약 :  india to launch in bengaluru
#
#
# 원문 : actress priyanka chopra morphed rumoured boyfriend nick jonas singapore gone viral internet shared widely priyanka nick originally photographed indonesian singer separately singer shared pictures instagram account
# 실제 요약 : sostoken priyanka chopra nick photo goes viral
# 예측 요약 :  priyanka nick girlfriend on her
#
#
# 원문 : google tracking users location data history even location tracking turned according associated press report found google services like google maps google search engine record android iphone users locations without permission last year similar reports emerged claiming google collecting users location data using towers
# 실제 요약 : sostoken google users even if is off report
# 예측 요약 :  google removes search engine
#
#
# 원문 : first odi sri lanka india reduced overs lowest ever total scored first odi india also second lowest ten score odis last five years first five overs four deliveries dot balls
# 실제 요약 : sostoken india post odi ever score in 1st
# 예측 요약 :  india beat sri lanka to take 1 000 runs in odi
#
#
# 원문 : hello initiative us based non profit organisation good creates tiny children put similar aimed making also getting children used seeing order help fight organisation goal people like muslim community around us
# 실제 요약 : sostoken creates for
# 예측 요약 :  us scientists develop to
#
#
# 원문 : harry potter series monday tweeted oh response article claiming world successful people start day always somewhere world person jokingly commented tweet ranked nd forbes list world highest paid year
# 실제 요약 : sostoken off on people up at 4
# 예측 요약 :  john asks world leaders to
#
#
# 원문 : justice monday nominated first woman chief justice pakistani high court take charge new role following retirement high court chief justice muhammad august became first woman civil judge
# 실제 요약 : sostoken pakistan gets its first woman chief justice of high court
# 예측 요약 :  first female chief justice of
#
#
# 원문 : actor salman khan reached mumbai granted bail towards fans gathered outside house go home sleep salman seen father khan nephew sharma fans balcony actor released jodhpur central jail earlier saturday spending two nights
# 실제 요약 : sostoken go home and salman to fans at mumbai house after bail
# 예측 요약 :  salman khan for
#
#
# 원문 : german dictator adolf hitler joined rejected german party time bigger successful nazi party newly discovered documents revealed hitler eventually turned nazi party becoming leader german party following year
# 실제 요약 : sostoken after being rejected by another party
# 예측 요약 :  german german president
#
#
# 원문 : us federal judge tuesday blocked president donald trump executive order sought federal funds cities saying president authority new conditions federal spending administration taking action appeal ruling win supreme court level point white house officials said
# 실제 요약 : sostoken judge blocks trump order to funds
# 예측 요약 :  us judge orders of trump
#
#
# 원문 : government reportedly set ordinance allowing increase cess luxury cars restore tax revenue automobile industry got affected transition gst notably gst council earlier recommended government raise cess luxury cars addition gst
# 실제 요약 : sostoken govt set to hike on cars under gst via
# 예측 요약 :  govt to hike for
#
#
# 원문 : maharashtra government planning introduce cycling tracks along roads cities including pune nagpur reports said four member committee constituted cycling track routes cycling tracks reduce traffic also environmental pollution public works department official said
# 실제 요약 : sostoken maharashtra to in 10
# 예측 요약 :  maha govt to set up to
#
#
# 원문 : indigo issued clarification twitter account called shared fake images airline introducing services immediate effect also retweeted post another account trolling airline airline slammed video fight passenger staffers went viral
# 실제 요약 : sostoken indigo says tweet is fake
# 예측 요약 :  indigo asks to find fake news
#
#
# 원문 : government set minimum net worth criteria bidding air india crore according reports reportedly airline negative net worth also bid provided form consortium net worth crore last year indigo expressed interest buy stake air india
# 실제 요약 : sostoken air india must have min ã¢ââ¹5 000 cr net worth reports
# 예측 요약 :  govt to sell crore to crore
#
#
# 원문 : tata steel closely following insolvency resolution process initiated banks acquire stressed assets dollar process insolvency resolution found transparent tata steel opportunities acquiring existing manufacturing capacity notably steel firms rbi bad loan accounts list
# 실제 요약 : sostoken tata steel looking to firms in bad loans list
# 예측 요약 :  tata steel to probe into
#
#
# 원문 : bjp mp hema malini said crimes women minors getting publicity days adding crimes may committed earlier well known stating government introduce measures malini said cases show india bad light comes amid widespread outrage kathua unnao rape cases
# 실제 요약 : sostoken against women getting more now
# 예측 요약 :  bjp mp calls for
#
#
# 원문 : reserve bank india established april british rule official double east india company logo originally featured lion tree later decided replace lion tiger represent india better
# 실제 요약 : sostoken rbi was inspired from india gold
# 예측 요약 :  rbi to issue on
#
#
# 원문 : two piece bikini named bikini site usa tested nuclear bombs first introduced years ago french designer louis july said first bikini small could fit like one model seen holding picture
# 실제 요약 : sostoken was named after site where us nuclear
# 예측 요약 :  video nuclear nuclear
#
#
# 원문 : allahabad high court friday directed cbi arrest bjp mla kuldeep singh accused raping year old girl uttar pradesh unnao cbi detained accused mla questioning earlier day comes government told hc sufficient evidence arrest
# 실제 요약 : sostoken hc orders arrest of bjp mla in rape case
# 예측 요약 :  cbi mla accused of rape accused in rape case
#
#
# 원문 : sri lankan captain dinesh coach manager handed ban two tests four odis acting spirit game punished protesting taking field windies second test last month accused ball tampering
# 실제 요약 : sostoken sl captain coach and manager banned for 2 tests 4 odis
# 예측 요약 :  sl captain banned for taking t20i
#
#
# 원문 : scientists discovered chemical skin types without need substance release dark skin would even fair individuals turn pink rather bronze sun due lack would lower skin cancer risk
# 실제 요약 : sostoken chemical all without cancer
# 예측 요약 :  researchers claim of
#
#
# 원문 : nasa one galaxies universe million years old current age light galaxies takes time reach earth allowing astronomers look universe history astronomers combined hubble space data obtained via gravitational predicted albert einstein century ago
# 실제 요약 : sostoken nasa from time when was 4 of its age
# 예측 요약 :  nasa probe into
#
#
# 원문 : supreme court overturned centre decision send cbi director alok verma indefinite leave giving back charge investigation agency verma asked leave following cbi special director rakesh asthana judgement two petitions one filed verma ngo
# 실제 요약 : sostoken gets back charge of cbi as sc govt's decision
# 예측 요약 :  cbi chief secretary resigns over
#
#
# 원문 : priyanka chopra rumoured fianc nick jonas recently told media family goal sure exact need give point added priyanka earlier said definitely wants kids next years earlier
# 실제 요약 : sostoken having family of my own the goal nick
# 예측 요약 :  nick is a nick on her relationship with
#
#
# 원문 : former england captain cook said would kept mouth shut retirement test cricket england india test series levelled year old batsman said revealed news english team drinking otherwise would actually
# 실제 요약 : sostoken shut on if series was 2 2 cook
# 예측 요약 :  i am not a for the world
#
#
# 원문 : tata sons chairman said major tcs committed encourage millions children across globe pursue science technology said tata group wants associated making contributions technologies every way help notably appointed tata sons chairman headed tcs
# 실제 요약 : sostoken tata kids to in chairman
# 예측 요약 :  tata on fire
#
#
# 원문 : government warned whatsapp take urgent steps prevent spread explosive messages platform leading cases lynching ministry electronics information technology said statement company cannot evade responsibility comes lynching incidents took place based forward messages circulated whatsapp
# 실제 요약 : sostoken govt warns whatsapp on to mob
# 예측 요약 :  whatsapp security security security
#
#
# 원문 : home ministry official revealed family terror group hizbul mujahideen commander wani wanted surrender wani relatives sought police intervention left home joined militancy age wani killed encounter security forces july last year
# 실제 요약 : sostoken family wanted him to home ministry
# 예측 요약 :  kin of martyred in
#
#
# 원문 : former pakistan high commissioner abdul thanked india bid country serving envoy delhi four years appointed high commissioner india tweeted india thanks everything expected take responsibilities around mid august
# 실제 요약 : sostoken india and thanks for former pak envoy
# 예측 요약 :  ex pak pm singh for
#
#
# 원문 : gujarat cm vijay rupani said firecrackers would go pakistan congress came power whereas firecrackers would burst gujarat bjp rupani speaking anand last day campaigning gujarat assembly elections earlier pm narendra modi suggested congress pakistan win polls
# 실제 요약 : sostoken will be in pakistan if cong wins guj cm
# 예측 요약 :  guj cm vijay
#
#
# 원문 : reacting zimbabwe recent odi series win sri lanka indian spinner ravichandran ashwin said results like healthy game tomorrow afghanistan may beat someone way sport needs added year old ashwin part india squad play first full series sri lanka eight years
# 실제 요약 : sostoken odi series win over sl ashwin
# 예측 요약 :  india has no right to play cricket in 2019
#
#
# 원문 : assam government released national register citizens final draft state congress chief said lakh people adding lot irregularities list meanwhile trinamool congress ss roy said centre intentionally minorities serious consequences states assam
# 실제 요약 : sostoken congress claims as 40 lakh left out from
# 예측 요약 :  assam govt to award
#
#
# 원문 : border roads organisation constructed world highest road height feet jammu kashmir constructed project km strategic road connects villages located km work involved life threatening challenges project chief engineer said
# 실제 요약 : sostoken world's highest road built at 19 in
# 예측 요약 :  bsf to build world's fastest in
#
#
# 원문 : teaser debut film salman khan brother law aayush sharma released also mark debut actress hussain actors star film include roy ram kapoor directed produced salman khan scheduled release october
# 실제 요약 : sostoken teaser of salman's brother in debut film out
# 예측 요약 :  teaser of salman khan starrer released
#
#
# 원문 : former us president barack obama friday said told prime minister narendra modi person country divided lines said indian society needs fact minorities particularly muslims india identify part nation common many countries
# 실제 요약 : sostoken told modi nation shouldn't be on obama
# 예측 요약 :  pm modi is a of india ex prez
#
#
# 원문 : new zealand mark dismissed hit wicket short ball struck helmet fell head pitch hit stumps th missed pull shot ball went hit head helmet came
# 실제 요약 : sostoken player hit on head by gets out as hits
# 예측 요약 :  ball hits the ball in one day
#
#
# 원문 : indian wicketkeeper dinesh karthik appointed new captain kolkata knight riders ahead th edition indian premier league franchise announced sunday robin named team vice captain kkr ceo thanked former captain gautam gambhir sold delhi daredevils contributions
# 실제 요약 : sostoken named captain of kolkata
# 예측 요약 :  to attend
#
#
# 원문 : indian premier league allow replacement player team england ben stokes case entire tournament due legal proceedings stokes became expensive overseas player ipl history auction charged incident outside bristol bar september last year
# 실제 요약 : sostoken ipl to allow if he
# 예측 요약 :  how did the of the world cup
#
#
# 원문 : heavy rains friday led traffic various parts national capital region took twitter ask delhi traffic police gurugram police help regarding traffic led exchange tweets two police forces wherein accused traffic
# 실제 요약 : sostoken delhi gurugram police each other for traffic
# 예측 요약 :  traffic in mumbai
#
#
# 원문 : got bigg boss entering top five said house real war outside opportunity experience fun like small kid aims win feels little disappointed added
# 실제 요약 : sostoken to have had this on bigg boss
# 예측 요약 :  i am a on
#
#
# 원문 : indian spinner ravichandran ashwin reportedly declined play county cricket feature june one test afghanistan ashwin received offer continue talks club committing play afghanistan maiden test team india captain virat kohli miss test owing county
# 실제 요약 : sostoken ashwin rejected offer to play afghanistan
# 예측 요약 :  ashwin to play in australia for 1st time in
#
#
# 원문 : researchers discovered malware information chrome capable stealing data like passwords credit cards profiles payment information infected devices spread via emails subject line online store developer required contains download
# 실제 요약 : sostoken that data from found
# 예측 요약 :  found in of
#
#
# 원문 : sanjay year old producer tv show committed suicide friday jumping th floor building mumbai per police suicide note also recovered cited depression financial issues reason committing suicide show stars mehta among others
# 실제 요약 : sostoken tv show producer sanjay commits suicide
# 예측 요약 :  tv actress commits suicide after
#
#
# 원문 : india coach ravi shastri defended team management decision keep ajinkya rahane first two tests south africa saying rohit sharma best option going current form ajinkya played first test done well would asked question rohit played said shastri
# 실제 요약 : sostoken shastri defends from first 2 tests
# 예측 요약 :  sa captain for to
#
#
# 원문 : addressing counter terror force national security guard union home minister rajnath singh said lone kind terror attacks major challenge us security agencies stated security forces great job handling terrorists adding need constantly update
# 실제 요약 : sostoken it terrorists are a major challenge rajnath
# 예측 요약 :  terror attacks in terror attacks
#
#
# 원문 : us judge awarded artists crore buildings displaying work owner artwork displayed area new york known owner sued visual artists rights act artists rights work even someone else owns physically
# 실제 요약 : sostoken us awarded crore over
# 예측 요약 :  us court orders to pay crore
#
#
# 원문 : bill tree passed goa legislative assembly tuesday earlier classified previous government making easy cut without formal permission one promises made goa forward party partner manohar parrikar led government
# 실제 요약 : sostoken goa assembly passes bill for as
# 예측 요약 :  passes away aged
#
#
# 원문 : many billion people around globe watched television wedding uk prince harry former american actress meghan markle st george according media reports couple given title palace
# 실제 요약 : sostoken 1 9 billion people prince harry marry actress

# %% [markdown]
# ### Step 5. Summa을 이용해서 추출적 요약해보기

# %%
# !pip list | grep summa
# Out:
# summa                         1.2.0

# %%
import requests
from summa.summarizer import summarize

# %%
text = requests.get('http://rare-technologies.com/the_matrix_synopsis.txt').text
print(text[:1500])
print('Headlines:')
print(summarize(text, ratio=0.005))
# Out:
# The screen is filled with green, cascading code which gives way to the title, The Matrix.
#
# A phone rings and text appears on the screen: "Call trans opt: received. 2-19-98 13:24:18 REC: Log>" As a conversation takes place between Trinity (Carrie-Anne Moss) and Cypher (Joe Pantoliano), two free humans, a table of random green numbers are being scanned and individual numbers selected, creating a series of digits not unlike an ordinary phone number, as if a code is being deciphered or a call is being traced.
#
# Trinity discusses some unknown person. Cypher taunts Trinity, suggesting she enjoys watching him. Trinity counters that "Morpheus (Laurence Fishburne) says he may be 'the One'," just as the sound of a number being selected alerts Trinity that someone may be tracing their call. She ends the call.
#
# Armed policemen move down a darkened, decrepit hallway in the Heart O' the City Hotel, their flashlight beam bouncing just ahead of them. They come to room 303, kick down the door and find a woman dressed in black, facing away from them. It's Trinity. She brings her hands up from the laptop she's working on at their command.
#
# Outside the hotel a car drives up and three agents appear in neatly pressed black suits. They are Agent Smith (Hugo Weaving), Agent Brown (Paul Goddard), and Agent Jones (Robert Taylor). Agent Smith and the presiding police lieutenant argue. Agent Smith admonishes the policeman that they were given specific orders to contact the agents first, for their
# Headlines:
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %%
print('Headlines:')
print(summarize(text, ratio=0.005, split=True))
print('Headlines:')
print(summarize(text, words=50))
# Out:
# Headlines:
# ['Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.', 'Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.']
# Headlines:
# Trinity takes Neo to Morpheus.
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.
